# %%
import pandas as pd

# %%
print(f'pandas version:{pd.__version__}')
# Out:
# pandas version:2.1.4

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(5)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 114      hyundai             sonata    3.3  2008    6    auto(l5)   f   19
# 56         dodge  dakota pickup 4wd    5.2  1999    8    auto(l4)   4   11
# 12          audi         a4 quattro    2.8  1999    6  manual(m5)   4   17
# 146       nissan             altima    3.5  2008    6    auto(av)   f   19
# 172       subaru        impreza awd    2.5  2008    4  manual(m5)   4   20
#
#      hwy fl    class
# 114   28  r  midsize
# 56    15  r   pickup
# 12    25  p  compact
# 146   26  p  midsize
# 172   27  r  compact

# %%
df=df[df.year==2008]
df.sample(5)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 60         dodge      durango 4wd    4.7  2008    8    auto(l5)   4   13   17
# 153       nissan   pathfinder 4wd    5.6  2008    8    auto(s5)   4   12   18
# 131   land rover      range rover    4.2  2008    8    auto(s6)   4   12   18
# 87          ford  f150 pickup 4wd    4.6  2008    8    auto(l4)   4   13   17
# 145       nissan           altima    3.5  2008    6  manual(m6)   f   19   27
#
#     fl    class
# 60   r      suv
# 153  p      suv
# 131  r      suv
# 87   r   pickup
# 145  p  midsize

# %%
df.shape
# Out:
# (117, 11)

# %%
df['cty'].mean()
# Out:
# 16.700854700854702

# %%
g=df.groupby('class')
g.groups
# Out:
# {'2seater': [25, 26, 27], 'compact': [2, 3, 6, 9, 10, 13, 14, 169, 170, 171, 172, 188, 189, 192, 196, 197, 209, 210, 215, 216, 217, 218], 'midsize': [16, 17, 33, 35, 36, 110, 111, 114, 143, 144, 145, 146, 149, 157, 158, 181, 182, 185, 229, 230, 233], 'minivan': [41, 42, 43, 46, 47], 'pickup': [48, 49, 52, 53, 54, 64, 65, 66, 67, 68, 69, 72, 87, 89, 202, 205, 206], 'subcompact': [92, 93, 96, 97, 98, 104, 105, 106, 107, 117, 118, 119, 120, 121, 225, 226], 'suv': [18, 19, 20, 22, 28, 29, 58, 59, 60, 62, 76, 80, 81, 122, 123, 126, 127, 128, 129, 131, 132, 136, 138, 139, 152, 153, 161, 162, 163, 164, 177, 178, 199]}

# %%
g.groups.keys()
# Out:
# dict_keys(['2seater', 'compact', 'midsize', 'minivan', 'pickup', 'subcompact', 'suv'])

# %%
g.get_group('compact').head()
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10         audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
#
#       class
# 2   compact
# 3   compact
# 6   compact
# 9   compact
# 10  compact

# %%
for k in g.groups.keys():
    print(f"{k} : {g.get_group(k)['cty'].mean()}")
# Out:
# 2seater : 15.333333333333334
# compact : 20.545454545454547
# midsize : 19.333333333333332
# minivan : 15.4
# pickup : 13.0
# subcompact : 18.9375
# suv : 13.606060606060606

# %%
g['cty'].mean()
# Out:
# class
# 2seater       15.333333
# compact       20.545455
# midsize       19.333333
# minivan       15.400000
# pickup        13.000000
# subcompact    18.937500
# suv           13.606061
# Name: cty, dtype: float64

# %% [markdown]
# ###  Correlation matrix

# %%
df.corr(numeric_only=True)
# Out:
#           displ  year       cyl       cty       hwy
# displ  1.000000   NaN  0.933354 -0.826688 -0.770264
# year        NaN   NaN       NaN       NaN       NaN
# cyl    0.933354   NaN  1.000000 -0.867462 -0.811891
# cty   -0.826688   NaN -0.867462  1.000000  0.964125
# hwy   -0.770264   NaN -0.811891  0.964125  1.000000

# %%
g.corr(numeric_only=True)
# Out:
#                      displ  year       cyl       cty       hwy
# class
# 2seater    displ  1.000000   NaN       NaN -0.500000 -0.866025
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl         NaN   NaN       NaN       NaN       NaN
#            cty   -0.500000   NaN       NaN  1.000000  0.866025
#            hwy   -0.866025   NaN       NaN  0.866025  1.000000
# compact    displ  1.000000   NaN  0.861838 -0.736410 -0.639915
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl    0.861838   NaN  1.000000 -0.600313 -0.413864
#            cty   -0.736410   NaN -0.600313  1.000000  0.894439
#            hwy   -0.639915   NaN -0.413864  0.894439  1.000000
# midsize    displ  1.000000   NaN  0.953447 -0.795621 -0.738020
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl    0.953447   NaN  1.000000 -0.879955 -0.864233
#            cty   -0.795621   NaN -0.879955  1.000000  0.882374
#            hwy   -0.738020   NaN -0.864233  0.882374  1.000000
# minivan    displ  1.000000   NaN       NaN  0.213335  0.242054
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl         NaN   NaN       NaN       NaN       NaN
#            cty    0.213335   NaN       NaN  1.000000  0.999544
#            hwy    0.242054   NaN       NaN  0.999544  1.000000
# pickup     displ  1.000000   NaN  0.904344 -0.566030 -0.518951
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl    0.904344   NaN  1.000000 -0.711369 -0.640095
#            cty   -0.566030   NaN -0.711369  1.000000  0.984007
#            hwy   -0.518951   NaN -0.640095  0.984007  1.000000
# subcompact displ  1.000000   NaN  0.935528 -0.830165 -0.784218
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl    0.935528   NaN  1.000000 -0.868536 -0.827693
#            cty   -0.830165   NaN -0.868536  1.000000  0.970655
#            hwy   -0.784218   NaN -0.827693  0.970655  1.000000
# suv        displ  1.000000   NaN  0.894183 -0.776411 -0.720637
#            year        NaN   NaN       NaN       NaN       NaN
#            cyl    0.894183   NaN  1.000000 -0.844158 -0.788482
#            cty   -0.776411   NaN -0.844158  1.000000  0.950597
#            hwy   -0.720637   NaN -0.788482  0.950597  1.000000

# %%
g[['cty','hwy','displ','cyl']].corr()
# Out:
#                        cty       hwy     displ       cyl
# class
# 2seater    cty    1.000000  0.866025 -0.500000       NaN
#            hwy    0.866025  1.000000 -0.866025       NaN
#            displ -0.500000 -0.866025  1.000000       NaN
#            cyl         NaN       NaN       NaN       NaN
# compact    cty    1.000000  0.894439 -0.736410 -0.600313
#            hwy    0.894439  1.000000 -0.639915 -0.413864
#            displ -0.736410 -0.639915  1.000000  0.861838
#            cyl   -0.600313 -0.413864  0.861838  1.000000
# midsize    cty    1.000000  0.882374 -0.795621 -0.879955
#            hwy    0.882374  1.000000 -0.738020 -0.864233
#            displ -0.795621 -0.738020  1.000000  0.953447
#            cyl   -0.879955 -0.864233  0.953447  1.000000
# minivan    cty    1.000000  0.999544  0.213335       NaN
#            hwy    0.999544  1.000000  0.242054       NaN
#            displ  0.213335  0.242054  1.000000       NaN
#            cyl         NaN       NaN       NaN       NaN
# pickup     cty    1.000000  0.984007 -0.566030 -0.711369
#            hwy    0.984007  1.000000 -0.518951 -0.640095
#            displ -0.566030 -0.518951  1.000000  0.904344
#            cyl   -0.711369 -0.640095  0.904344  1.000000
# subcompact cty    1.000000  0.970655 -0.830165 -0.868536
#            hwy    0.970655  1.000000 -0.784218 -0.827693
#            displ -0.830165 -0.784218  1.000000  0.935528
#            cyl   -0.868536 -0.827693  0.935528  1.000000
# suv        cty    1.000000  0.950597 -0.776411 -0.844158
#            hwy    0.950597  1.000000 -0.720637 -0.788482
#            displ -0.776411 -0.720637  1.000000  0.894183
#            cyl   -0.844158 -0.788482  0.894183  1.000000

# %% [markdown]
# ### Split-apply-combine

# %% [markdown]
# #### nlargest

# %%
df.nlargest(1,'cty')
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  cty  hwy fl  \
# 196       toyota  corolla    1.8  2008    4  manual(m5)   f   28   37  r
#
#        class
# 196  compact

# %%
g=df.groupby('class')

# %%
g.groups
# Out:
# {'2seater': [25, 26, 27], 'compact': [2, 3, 6, 9, 10, 13, 14, 169, 170, 171, 172, 188, 189, 192, 196, 197, 209, 210, 215, 216, 217, 218], 'midsize': [16, 17, 33, 35, 36, 110, 111, 114, 143, 144, 145, 146, 149, 157, 158, 181, 182, 185, 229, 230, 233], 'minivan': [41, 42, 43, 46, 47], 'pickup': [48, 49, 52, 53, 54, 64, 65, 66, 67, 68, 69, 72, 87, 89, 202, 205, 206], 'subcompact': [92, 93, 96, 97, 98, 104, 105, 106, 107, 117, 118, 119, 120, 121, 225, 226], 'suv': [18, 19, 20, 22, 28, 29, 58, 59, 60, 62, 76, 80, 81, 122, 123, 126, 127, 128, 129, 131, 132, 136, 138, 139, 152, 153, 161, 162, 163, 164, 177, 178, 199]}

# %%
g.get_group('compact').nlargest(3,'cty')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 196       toyota       corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 197       toyota       corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 189       toyota  camry solara    2.4  2008    4    auto(s5)   f   22   31  r
#
#        class
# 196  compact
# 197  compact
# 189  compact

# %%
g.get_group('suv').nlargest(3,'cty')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 161       subaru  forester awd    2.5  2008    4  manual(m5)   4   20   27  r
# 163       subaru  forester awd    2.5  2008    4    auto(l4)   4   20   26  r
# 162       subaru  forester awd    2.5  2008    4  manual(m5)   4   19   25  p
#
#     class
# 161   suv
# 163   suv
# 162   suv

# %%
g.apply(lambda grp: grp.nlargest(1,'cty'))
# Out:
#                manufacturer              model  displ  year  cyl       trans  \
# class
# 2seater    25     chevrolet           corvette    6.2  2008    8  manual(m6)
# compact    196       toyota            corolla    1.8  2008    4  manual(m5)
# midsize    143       nissan             altima    2.5  2008    4    auto(av)
# minivan    41         dodge        caravan 2wd    3.3  2008    6    auto(l4)
# pickup     202       toyota  toyota tacoma 4wd    2.7  2008    4  manual(m5)
# subcompact 104        honda              civic    1.8  2008    4  manual(m5)
# suv        161       subaru       forester awd    2.5  2008    4  manual(m5)
#
#                drv  cty  hwy fl       class
# class
# 2seater    25    r   16   26  p     2seater
# compact    196   f   28   37  r     compact
# midsize    143   f   23   31  r     midsize
# minivan    41    f   17   24  r     minivan
# pickup     202   4   17   22  r      pickup
# subcompact 104   f   26   34  r  subcompact
# suv        161   4   20   27  r         suv

# %%
g.apply(lambda grp: grp.nlargest(1,'cty')).sort_values('cty',ascending=False)
# Out:
#                manufacturer              model  displ  year  cyl       trans  \
# class
# compact    196       toyota            corolla    1.8  2008    4  manual(m5)
# subcompact 104        honda              civic    1.8  2008    4  manual(m5)
# midsize    143       nissan             altima    2.5  2008    4    auto(av)
# suv        161       subaru       forester awd    2.5  2008    4  manual(m5)
# minivan    41         dodge        caravan 2wd    3.3  2008    6    auto(l4)
# pickup     202       toyota  toyota tacoma 4wd    2.7  2008    4  manual(m5)
# 2seater    25     chevrolet           corvette    6.2  2008    8  manual(m6)
#
#                drv  cty  hwy fl       class
# class
# compact    196   f   28   37  r     compact
# subcompact 104   f   26   34  r  subcompact
# midsize    143   f   23   31  r     midsize
# suv        161   4   20   27  r         suv
# minivan    41    f   17   24  r     minivan
# pickup     202   4   17   22  r      pickup
# 2seater    25    r   16   26  p     2seater

# %% [markdown]
# ### Multilevel group

# %%
g2=df.groupby(['class','drv'])
g2.groups
# Out:
# {('2seater', 'r'): [25, 26, 27], ('compact', '4'): [9, 10, 13, 14, 169, 170, 171, 172], ('compact', 'f'): [2, 3, 6, 188, 189, 192, 196, 197, 209, 210, 215, 216, 217, 218], ('midsize', '4'): [16, 17], ('midsize', 'f'): [33, 35, 36, 110, 111, 114, 143, 144, 145, 146, 149, 157, 158, 181, 182, 185, 229, 230, 233], ('minivan', 'f'): [41, 42, 43, 46, 47], ('pickup', '4'): [48, 49, 52, 53, 54, 64, 65, 66, 67, 68, 69, 72, 87, 89, 202, 205, 206], ('subcompact', 'f'): [104, 105, 106, 107, 117, 118, 119, 120, 121, 225, 226], ('subcompact', 'r'): [92, 93, 96, 97, 98], ('suv', '4'): [28, 29, 58, 59, 60, 62, 80, 81, 122, 123, 126, 127, 128, 129, 131, 132, 138, 139, 152, 153, 161, 162, 163, 164, 177, 178, 199], ('suv', 'r'): [18, 19, 20, 22, 76, 136]}

# %%
g2[['cty','hwy']].mean()
# Out:
#                       cty        hwy
# class      drv
# 2seater    r    15.333333  25.000000
# compact    4    18.750000  26.125000
#            f    21.571429  30.214286
# midsize    4    16.500000  24.000000
#            f    19.631579  28.473684
# minivan    f    15.400000  22.200000
# pickup     4    13.000000  16.941176
# subcompact f    20.545455  29.000000
#            r    15.400000  23.000000
# suv        4    13.851852  18.777778
#            r    12.500000  18.000000

# %%
g2.describe()[['cty','hwy']]
# Out:
#                  cty                                                       \
#                count       mean       std   min    25%   50%    75%   max
# class      drv
# 2seater    r     3.0  15.333333  0.577350  15.0  15.00  15.0  15.50  16.0
# compact    4     8.0  18.750000  1.832251  15.0  18.50  19.5  20.00  20.0
#            f    14.0  21.571429  2.651974  18.0  21.00  21.0  22.00  28.0
# midsize    4     2.0  16.500000  0.707107  16.0  16.25  16.5  16.75  17.0
#            f    19.0  19.631579  2.005839  16.0  18.50  19.0  21.00  23.0
# minivan    f     5.0  15.400000  2.509980  11.0  16.00  16.0  17.00  17.0
# pickup     4    17.0  13.000000  2.318405   9.0  12.00  13.0  14.00  17.0
# subcompact f    11.0  20.545455  3.297382  16.0  18.50  20.0  22.50  26.0
#            r     5.0  15.400000  1.140175  14.0  15.00  15.0  16.00  17.0
# suv        4    27.0  13.851852  2.878350   9.0  12.50  13.0  14.50  20.0
#            r     6.0  12.500000  1.224745  11.0  12.00  12.0  13.50  14.0
#
#                  hwy
#                count       mean       std   min    25%   50%   75%   max
# class      drv
# 2seater    r     3.0  25.000000  1.000000  24.0  24.50  25.0  25.5  26.0
# compact    4     8.0  26.125000  1.246423  25.0  25.00  26.0  27.0  28.0
#            f    14.0  30.214286  2.778449  27.0  29.00  29.0  31.0  37.0
# midsize    4     2.0  24.000000  1.414214  23.0  23.50  24.0  24.5  25.0
#            f    19.0  28.473684  2.220321  25.0  26.50  28.0  30.5  32.0
# minivan    f     5.0  22.200000  2.949576  17.0  23.00  23.0  24.0  24.0
# pickup     4    17.0  16.941176  2.794427  12.0  16.00  17.0  19.0  22.0
# subcompact f    11.0  29.000000  4.516636  24.0  25.50  28.0  31.5  36.0
#            r     5.0  23.000000  2.236068  20.0  22.00  23.0  24.0  26.0
# suv        4    27.0  18.777778  3.619746  12.0  17.50  19.0  19.5  27.0
#            r     6.0  18.000000  1.897367  15.0  17.25  18.0  19.5  20.0

# %% [markdown]
# ### Rank within group

# %%
g=df.groupby('class')
g.groups
# Out:
# {'2seater': [25, 26, 27], 'compact': [2, 3, 6, 9, 10, 13, 14, 169, 170, 171, 172, 188, 189, 192, 196, 197, 209, 210, 215, 216, 217, 218], 'midsize': [16, 17, 33, 35, 36, 110, 111, 114, 143, 144, 145, 146, 149, 157, 158, 181, 182, 185, 229, 230, 233], 'minivan': [41, 42, 43, 46, 47], 'pickup': [48, 49, 52, 53, 54, 64, 65, 66, 67, 68, 69, 72, 87, 89, 202, 205, 206], 'subcompact': [92, 93, 96, 97, 98, 104, 105, 106, 107, 117, 118, 119, 120, 121, 225, 226], 'suv': [18, 19, 20, 22, 28, 29, 58, 59, 60, 62, 76, 80, 81, 122, 123, 126, 127, 128, 129, 131, 132, 136, 138, 139, 152, 153, 161, 162, 163, 164, 177, 178, 199]}

# %%
df['rank']=g['cty'].rank('dense',ascending=False)
df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2           audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 6           audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 9           audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10          audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 225   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 226   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
# 229   volkswagen      passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen      passat    2.0  2008    4  manual(m6)   f   21   29  p
# 233   volkswagen      passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#           class  rank
# 2       compact   5.0
# 3       compact   4.0
# 6       compact   7.0
# 9       compact   5.0
# 10      compact   6.0
# ..          ...   ...
# 225  subcompact   5.0
# 226  subcompact   5.0
# 229     midsize   4.0
# 230     midsize   3.0
# 233     midsize   6.0
#
# [117 rows x 12 columns]

# %%
df[df['class']=='compact'].sort_values('rank')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 196       toyota       corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 197       toyota       corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 215   volkswagen         jetta    2.0  2008    4    auto(s6)   f   22   29  p
# 210   volkswagen           gti    2.0  2008    4    auto(s6)   f   22   29  p
# 189       toyota  camry solara    2.4  2008    4    auto(s5)   f   22   31  r
# 218   volkswagen         jetta    2.5  2008    5  manual(m5)   f   21   29  r
# 3           audi            a4    2.0  2008    4    auto(av)   f   21   30  p
# 216   volkswagen         jetta    2.0  2008    4  manual(m6)   f   21   29  p
# 209   volkswagen           gti    2.0  2008    4  manual(m6)   f   21   29  p
# 188       toyota  camry solara    2.4  2008    4  manual(m5)   f   21   31  r
# 217   volkswagen         jetta    2.5  2008    5    auto(s6)   f   21   29  r
# 2           audi            a4    2.0  2008    4  manual(m6)   f   20   31  p
# 170       subaru   impreza awd    2.5  2008    4    auto(s4)   4   20   27  r
# 169       subaru   impreza awd    2.5  2008    4    auto(s4)   4   20   25  p
# 9           audi    a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 172       subaru   impreza awd    2.5  2008    4  manual(m5)   4   20   27  r
# 10          audi    a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 171       subaru   impreza awd    2.5  2008    4  manual(m5)   4   19   25  p
# 192       toyota  camry solara    3.3  2008    6    auto(s5)   f   18   27  r
# 6           audi            a4    3.1  2008    6    auto(av)   f   18   27  p
# 13          audi    a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 14          audi    a4 quattro    3.1  2008    6  manual(m6)   4   15   25  p
#
#        class  rank
# 196  compact   1.0
# 197  compact   2.0
# 215  compact   3.0
# 210  compact   3.0
# 189  compact   3.0
# 218  compact   4.0
# 3    compact   4.0
# 216  compact   4.0
# 209  compact   4.0
# 188  compact   4.0
# 217  compact   4.0
# 2    compact   5.0
# 170  compact   5.0
# 169  compact   5.0
# 9    compact   5.0
# 172  compact   5.0
# 10   compact   6.0
# 171  compact   6.0
# 192  compact   7.0
# 6    compact   7.0
# 13   compact   8.0
# 14   compact   9.0

# %%
df.sort_values(by=['class','rank'])
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 25     chevrolet            corvette    6.2  2008    8  manual(m6)   r   16
# 26     chevrolet            corvette    6.2  2008    8    auto(s6)   r   15
# 27     chevrolet            corvette    7.0  2008    8  manual(m6)   r   15
# 196       toyota             corolla    1.8  2008    4  manual(m5)   f   28
# 197       toyota             corolla    1.8  2008    4    auto(l4)   f   26
# ..           ...                 ...    ...   ...  ...         ...  ..  ...
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 29     chevrolet     k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 129         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)   4   11
# 59         dodge         durango 4wd    4.7  2008    8    auto(l5)   4    9
# 126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl    class  rank
# 25    26  p  2seater   1.0
# 26    25  p  2seater   2.0
# 27    24  p  2seater   2.0
# 196   37  r  compact   1.0
# 197   35  r  compact   2.0
# ..   ... ..      ...   ...
# 19    15  e      suv  10.0
# 29    14  e      suv  10.0
# 129   14  p      suv  10.0
# 59    12  e      suv  11.0
# 126   12  e      suv  11.0
#
# [117 rows x 12 columns]

# %%
g.apply(lambda grp:grp.sort_values(by=['rank']))
# Out:
#             manufacturer               model  displ  year  cyl       trans  \
# class
# 2seater 25     chevrolet            corvette    6.2  2008    8  manual(m6)
#         26     chevrolet            corvette    6.2  2008    8    auto(s6)
#         27     chevrolet            corvette    7.0  2008    8  manual(m6)
# compact 196       toyota             corolla    1.8  2008    4  manual(m5)
#         197       toyota             corolla    1.8  2008    4    auto(l4)
# ...                  ...                 ...    ...   ...  ...         ...
# suv     129         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)
#         29     chevrolet     k1500 tahoe 4wd    5.3  2008    8    auto(l4)
#         19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)
#         59         dodge         durango 4wd    4.7  2008    8    auto(l5)
#         126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)
#
#             drv  cty  hwy fl    class  rank
# class
# 2seater 25    r   16   26  p  2seater   1.0
#         26    r   15   25  p  2seater   2.0
#         27    r   15   24  p  2seater   2.0
# compact 196   f   28   37  r  compact   1.0
#         197   f   26   35  r  compact   2.0
# ...          ..  ...  ... ..      ...   ...
# suv     129   4   11   14  p      suv  10.0
#         29    4   11   14  e      suv  10.0
#         19    r   11   15  e      suv  10.0
#         59    4    9   12  e      suv  11.0
#         126   4    9   12  e      suv  11.0
#
# [117 rows x 12 columns]
