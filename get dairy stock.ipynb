# %%
# Define the ticker list
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Fetch the data
import yfinance as yf
data = yf.download(tickers_list,'2015-1-1')['Adj Close']

import matplotlib.pyplot as plt
# %matplotlib inline
# Print first 5 rows of the data
print(data.head())
# Out:
# [*********************100%%**********************]  6 of 6 completed
#                  AAPL        AXP          BA         IBM         MU        WMT
# Date
# 2015-01-02  24.466448  81.284050  113.657227  104.297096  34.207642  71.167419
# 2015-01-05  23.777193  79.134399  112.870064  102.655998  33.252781  70.960297
# 2015-01-06  23.779436  77.447922  111.540619  100.442101  32.356983  71.507095
# 2015-01-07  24.112867  79.139374  113.272362   99.785667  31.599001  73.404327
# 2015-01-08  25.039337  80.261177  115.275261  101.954514  33.144493  74.953606

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2263 entries, 2015-01-02 to 2023-12-28
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2263 non-null   float64
#  1   AXP     2263 non-null   float64
#  2   BA      2263 non-null   float64
#  3   IBM     2263 non-null   float64
#  4   MU      2263 non-null   float64
#  5   WMT     2263 non-null   float64
# dtypes: float64(6)
# memory usage: 188.3 KB

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
data.unstack()
# Out:
#       Date
# AAPL  2015-01-02     24.466448
#       2015-01-05     23.777193
#       2015-01-06     23.779436
#       2015-01-07     24.112867
#       2015-01-08     25.039337
#                        ...
# WMT   2023-12-21    154.800003
#       2023-12-22    156.649994
#       2023-12-26    156.410004
#       2023-12-27    157.880005
#       2023-12-28    158.035004
# Length: 13578, dtype: float64

# %%
data.unstack().to_frame()
# Out:
#                           0
#      Date
# AAPL 2015-01-02   24.466448
#      2015-01-05   23.777193
#      2015-01-06   23.779436
#      2015-01-07   24.112867
#      2015-01-08   25.039337
# ...                     ...
# WMT  2023-12-21  154.800003
#      2023-12-22  156.649994
#      2023-12-26  156.410004
#      2023-12-27  157.880005
#      2023-12-28  158.035004
#
# [13578 rows x 1 columns]

# %%
data=data.rename(columns={0:'value'})
data
# Out:
#                   AAPL         AXP          BA         IBM         MU  \
# Date
# 2015-01-02   24.466448   81.284050  113.657227  104.297096  34.207642
# 2015-01-05   23.777193   79.134399  112.870064  102.655998  33.252781
# 2015-01-06   23.779436   77.447922  111.540619  100.442101  32.356983
# 2015-01-07   24.112867   79.139374  113.272362   99.785667  31.599001
# 2015-01-08   25.039337   80.261177  115.275261  101.954514  33.144493
# ...                ...         ...         ...         ...        ...
# 2023-12-21  194.679993  184.789993  262.019989  160.779999  85.480003
# 2023-12-22  193.600006  185.570007  260.440002  162.139999  86.489998
# 2023-12-26  193.050003  185.960007  262.790009  163.210007  87.059998
# 2023-12-27  193.149994  187.059998  262.100006  163.460007  86.660004
# 2023-12-28  194.210999  187.979996  259.579803  163.824997  86.195000
#
#                    WMT
# Date
# 2015-01-02   71.167419
# 2015-01-05   70.960297
# 2015-01-06   71.507095
# 2015-01-07   73.404327
# 2015-01-08   74.953606
# ...                ...
# 2023-12-21  154.800003
# 2023-12-22  156.649994
# 2023-12-26  156.410004
# 2023-12-27  157.880005
# 2023-12-28  158.035004
#
# [2263 rows x 6 columns]
